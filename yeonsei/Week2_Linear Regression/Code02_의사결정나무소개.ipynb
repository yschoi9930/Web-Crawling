# %% [markdown]
# # 분류나무 예시

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # version 0.11.0
sns.__version__
# Out:
# '0.11.0'

# %%
# !pip install --upgrade seaborn : seaborn 패키지 업그레이드

# %%
df1 = pd.read_csv('sample1.csv')
X = df1.drop('y', axis=1)
y = df1['y']

# %%
sns.scatterplot(data=df1, x='x1', y='x2', hue='y')#, palette="Set2")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
c_tree = DecisionTreeClassifier(min_impurity_decrease=0.05,random_state=0)
c_tree.fit(X, y)
# Out:
# DecisionTreeClassifier(min_impurity_decrease=0.05, random_state=0)

# %% [markdown]
# ### 나무 모형

# %%
xname = X.columns
yname = ['0','1']
plt.figure(figsize=(10,8))
plot_tree(c_tree, feature_names=xname, class_names=yname, filled=True, fontsize=12) 
plt.show()

# %% [markdown]
# # 분류나무 예제 (구매여부 데이터)

# %%
direct2 = pd.read_csv('direct2.csv')
direct2
# Out:
#       Buy   Age  Gender  Married  Children  Income  Ccard  Recent  Climate  \
# 0       0  71.0       0      1.0         1     486      1       1       17
# 1       1  53.0       0      1.0         3     620      2       0       20
# 2       0  53.0       1      1.0         0     694      5       1       18
# 3       0  45.0       1      0.0         0     582      3       1       15
# 4       1  32.0       1      0.0         0     419      5       0       16
# ...   ...   ...     ...      ...       ...     ...    ...     ...      ...
# 9995    1  41.0       1      1.0         2     674      1       0       16
# 9996    0  54.0       0      1.0         1     576      1       1       14
# 9997    0  47.0       1      0.0         0     589      6       0       15
# 9998    1  51.0       1      1.0         1     556      2       1       17
# 9999    0  50.0       1      1.0         1     772      6       0       17
#
#       Urban
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
# ...     ...
# 9995      1
# 9996      1
# 9997      1
# 9998      1
# 9999      0
#
# [10000 rows x 10 columns]

# %%
direct2 = direct2.dropna() # missing value 제거
print(direct2.isnull().sum()) 
X = direct2.drop('Buy',axis = 'columns')
y = direct2['Buy']
# Out:
# Buy         0
# Age         0
# Gender      0
# Married     0
# Children    0
# Income      0
# Ccard       0
# Recent      0
# Climate     0
# Urban       0
# dtype: int64

# %% [markdown]
# ### 분류나무 모형

# %%
model_tree = DecisionTreeClassifier(max_depth=2,random_state=0)
model_tree.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
plt.figure(figsize=(12, 6))
xname = X.columns
yname = ['Nonbuyer','Buyer']
plot_tree(model_tree, feature_names=xname, class_names=yname, filled=True, fontsize=12) 
plt.show()

# %% [markdown]
# # 회귀나무 예시

# %%
df2 = pd.read_csv('sample2.csv')
X = df2.drop('y', axis=1)
y = df2['y']
sns.scatterplot(data=df2, x='x', y='y', palette="Set2")
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
r_tree = DecisionTreeRegressor(min_impurity_decrease=10, random_state=0) 
r_tree.fit(X, y)
# Out:
# DecisionTreeRegressor(min_impurity_decrease=10, random_state=0)

# %% [markdown]
# ### 나무 모형

# %%
plt.figure(figsize=(10,8))
xname = X.columns
plot_tree(r_tree, feature_names=xname, filled=True, fontsize=12) 
plt.show()

# %% [markdown]
# # 회귀나무 예제 (CAT 점수 데이터)

# %%
df=pd.read_csv('copdcat.csv' ,header=0)
X=df.drop(["CATScore"],axis=1)
y=df["CATScore"]

# %% [markdown]
# ### 회귀나무 모형

# %%
model_tree = DecisionTreeRegressor(max_depth=2, random_state=0)
fit_tree = model_tree.fit(X, y)

# %%
plt.figure(figsize=(10, 6))
xname = X.columns
plot_tree(fit_tree, feature_names=xname, filled=True, fontsize=12) 
plt.show()
